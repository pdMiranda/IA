# %% [markdown]
# **Instalando biblioteca**

# %%
pip install chefboost

# %% [markdown]
# **Importando bibliotecas**

# %%
from chefboost import Chefboost as chef
import pandas as pd

# %% [markdown]
# **Lendo base CSV (no GitHub)**

# %%
base = pd.read_csv("https://raw.githubusercontent.com/pdMiranda/IA/main/Dados/risco.txt")
base
# Out:
#    HistoriaCredito Divida Garantias   RendaAnual  Decision
# 0             Ruim   Alta   Nenhuma       <15000      Alto
# 1     Desconhecida   Alta   Nenhuma  15000-35000      Alto
# 2     Desconhecida  Baixa   Nenhuma  15000-35000  Moderado
# 3     Desconhecida  Baixa   Nenhuma       >35000      Alto
# 4     Desconhecida  Baixa   Nenhuma       >35000     Baixo
# 5     Desconhecida  Baixa  Adequada       >35000     Baixo
# 6             Ruim  Baixa   Nenhuma       <15000      Alto
# 7             Ruim  Baixa  Adequada       >35000  Moderado
# 8              Boa  Baixa   Nenhuma       >35000     Baixo
# 9              Boa   Alta  Adequada       >35000     Baixo
# 10             Boa   Alta   Nenhuma       <15000      Alto
# 11             Boa   Alta   Nenhuma  15000-35000  Moderado
# 12             Boa   Alta   Nenhuma       >35000     Baixo
# 13            Ruim   Alta   Nenhuma  15000-35000      Alto

# %% [markdown]
# **Configurando e rodando algoritmo de árvore de decisão (ID3)**

# %%
config = {'algorithm': 'ID3'}
modelo = chef.fit(base, config = config, target_label = 'Decision')
# Out:
# [INFO]:  1 CPU cores will be allocated in parallel running
# ID3  tree is going to be built...
# -------------------------
# finished in  1.6123862266540527  seconds
# -------------------------
# Evaluate  train set
# -------------------------
# Accuracy:  92.85714285714286 % on  14  instances
# Labels:  ['Alto' 'Moderado' 'Baixo']
# Confusion matrix:  [[6, 0, 1], [0, 3, 0], [0, 0, 4]]
# Decision  Alto  => Accuray:  92.8571 %, Precision:  85.7143 %, Recall:  100.0 %, F1:  92.3077 %
# Decision  Moderado  => Accuray:  100.0 %, Precision:  100.0 %, Recall:  100.0 %, F1:  100.0 %
# Decision  Baixo  => Accuray:  92.8571 %, Precision:  100.0 %, Recall:  80.0 %, F1:  88.8889 %

# %% [markdown]
# # Nova seção
